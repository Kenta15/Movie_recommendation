# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_original=pd.read_csv("dataset/movie_metadata.csv")
df_original.head(10)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
# 6  Color          Sam Raimi                   392.0     156.0
# 7  Color       Nathan Greno                   324.0     100.0
# 8  Color        Joss Whedon                   635.0     141.0
# 9  Color        David Yates                   375.0     153.0
#
#    director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                      0.0                   855.0   Joel David Moore
# 1                    563.0                  1000.0      Orlando Bloom
# 2                      0.0                   161.0       Rory Kinnear
# 3                  22000.0                 23000.0     Christian Bale
# 4                    131.0                     NaN         Rob Walker
# 5                    475.0                   530.0    Samantha Morton
# 6                      0.0                  4000.0       James Franco
# 7                     15.0                   284.0       Donna Murphy
# 8                      0.0                 19000.0  Robert Downey Jr.
# 9                    282.0                 10000.0   Daniel Radcliffe
#
#    actor_1_facebook_likes        gross  \
# 0                  1000.0  760505847.0
# 1                 40000.0  309404152.0
# 2                 11000.0  200074175.0
# 3                 27000.0  448130642.0
# 4                   131.0          NaN
# 5                   640.0   73058679.0
# 6                 24000.0  336530303.0
# 7                   799.0  200807262.0
# 8                 26000.0  458991599.0
# 9                 25000.0  301956980.0
#
#                                               genres  ...  \
# 0                    Action|Adventure|Fantasy|Sci-Fi  ...
# 1                           Action|Adventure|Fantasy  ...
# 2                          Action|Adventure|Thriller  ...
# 3                                    Action|Thriller  ...
# 4                                        Documentary  ...
# 5                            Action|Adventure|Sci-Fi  ...
# 6                           Action|Adventure|Romance  ...
# 7  Adventure|Animation|Comedy|Family|Fantasy|Musi...  ...
# 8                            Action|Adventure|Sci-Fi  ...
# 9                   Adventure|Family|Fantasy|Mystery  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
# 5                738.0  English      USA           PG-13  263700000.0
# 6               1902.0  English      USA           PG-13  258000000.0
# 7                387.0  English      USA              PG  260000000.0
# 8               1117.0  English      USA           PG-13  250000000.0
# 9                973.0  English       UK              PG  250000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
# 5      2012.0                  632.0        6.6          2.35
# 6      2007.0                11000.0        6.2          2.35
# 7      2010.0                  553.0        7.8          1.85
# 8      2015.0                21000.0        7.5          2.35
# 9      2009.0                11000.0        7.5          2.35
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
# 5                24000
# 6                    0
# 7                29000
# 8               118000
# 9                10000
#
# [10 rows x 28 columns]

# %%
df_original = df_original.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
df_original
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 5038        Scott Smith      Eric Mabius     Daphne Zuniga
# 5039                NaN      Natalie Zea     Valorie Curry
# 5040   Benjamin Roberds      Eva Boehnke     Maxwell Moody
# 5041        Daniel Hsia        Alan Ruck     Daniel Henney
# 5042           Jon Gunn      John August  Brian Herzlinger
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action|Adventure|Fantasy|Sci-Fi
# 1           Jack Davenport         Action|Adventure|Fantasy
# 2         Stephanie Sigman        Action|Adventure|Thriller
# 3     Joseph Gordon-Levitt                  Action|Thriller
# 4                      NaN                      Documentary
# ...                    ...                              ...
# 5038          Crystal Lowe                     Comedy|Drama
# 5039         Sam Underwood     Crime|Drama|Mystery|Thriller
# 5040        David Chandler            Drama|Horror|Thriller
# 5041           Eliza Coupe             Comedy|Drama|Romance
# 5042              Jon Gunn                      Documentary
#
#                                             movie_title
# 0                                               Avatar
# 1             Pirates of the Caribbean: At World's End
# 2                                              Spectre
# 3                                The Dark Knight Rises
# 4     Star Wars: Episode VII - The Force Awakens    ...
# ...                                                 ...
# 5038                           Signed Sealed Delivered
# 5039                         The Following
# 5040                              A Plague So Pleasant
# 5041                                  Shanghai Calling
# 5042                                 My Date with Drew
#
# [5043 rows x 6 columns]

# %%
df_original['actor_1_name'] = df_original['actor_1_name'].replace(np.nan, 'unknown') # replacing null values to "unknown"
df_original['actor_2_name'] = df_original['actor_2_name'].replace(np.nan, 'unknown')
df_original['actor_3_name'] = df_original['actor_3_name'].replace(np.nan, 'unknown')
df_original['director_name'] = df_original['director_name'].replace(np.nan, 'unknown')

# %%
df_original['genres'] = df_original['genres'].str.replace('|', ' ') # removing unnessesary bars
# Out:
# /var/folders/g_/c68jffzd7552c4ffzwzthm1h0000gn/T/ipykernel_84883/1402137748.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_original['genres'] = df_original['genres'].str.replace('|', ' ') # removing unnessesary bars

# %%
df_original['movie_title'] = df_original['movie_title'].str.lower() # lowering titile for the sake of simplicity

# %%
df_original['movie_title'] = df_original['movie_title'].apply(lambda x : x[:-1]) # removing unnessesary chars at the end of the titile

# %%
from tmdbv3api import TMDb
import imdb
import json
import requests
from tmdbv3api import Movie
tmdb = TMDb()
tmdb.api_key = '87f1f400a3e1445d86fdd4366532e611'

# %%
# fetching genres using API
tmdb_movie = Movie()
def get_genre(x):    
        genres = []
        result = tmdb_movie.search(x)
        if result != []:
                movie_id = result[0].id
                response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
                data_json = response.json()
                if data_json['genres']:
                        genre_str = " " 
                        for i in range(len(data_json['genres'])):
                                genres.append(data_json['genres'][i]['name'])
                        return genre_str.join(genres)

# %%
# scraping movies 2018 to 2022 from wikipedia
movies_info = []

for i in range(5):
    link = "https://en.wikipedia.org/wiki/List_of_American_films_of_" + str(i+2018)
    df1 = pd.read_html(link, header=0)[2]
    df2 = pd.read_html(link, header=0)[3]
    df3 = pd.read_html(link, header=0)[4]
    df4 = pd.read_html(link, header=0)[5]
    df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

    movies_info.append(df)
# Out:
# /var/folders/g_/c68jffzd7552c4ffzwzthm1h0000gn/T/ipykernel_84883/1583965180.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# /var/folders/g_/c68jffzd7552c4ffzwzthm1h0000gn/T/ipykernel_84883/1583965180.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# /var/folders/g_/c68jffzd7552c4ffzwzthm1h0000gn/T/ipykernel_84883/1583965180.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# /var/folders/g_/c68jffzd7552c4ffzwzthm1h0000gn/T/ipykernel_84883/1583965180.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# /var/folders/g_/c68jffzd7552c4ffzwzthm1h0000gn/T/ipykernel_84883/1583965180.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
# adding the genre to the column for each dataset
for i in range(5):
    movies_info[i]['genres'] = movies_info[i]['Title'].map(lambda x: get_genre(str(x)))

# %%
# setting up functions to get each person from Cast and crew
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])
    
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
for i in range(5):
    movies_info[i] = movies_info[i][['Title','Cast and crew','genres']]
    movies_info[i] = movies_info[i].rename(columns={'Title':'movie_title'})
    movies_info[i]['director_name'] = movies_info[i]['Cast and crew'].map(lambda x: get_director(str(x)))
    movies_info[i]['actor_1_name'] = movies_info[i]['Cast and crew'].map(lambda x: get_actor1(str(x)))
    movies_info[i]['actor_2_name'] = movies_info[i]['Cast and crew'].map(lambda x: get_actor2(str(x)))
    movies_info[i]['actor_3_name'] = movies_info[i]['Cast and crew'].map(lambda x: get_actor3(str(x)))
    movies_info[i].loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
    movies_info[i]['movie_title'] = movies_info[i]['movie_title'].str.lower()
    movies_info[i]['comb'] = movies_info[i]['actor_1_name'] + ' ' + movies_info[i]['actor_2_name'] + ' '+ movies_info[i]['actor_3_name'] + ' '+ movies_info[i]['director_name'] +' ' + movies_info[i]['genres']
movies_info[3]
# Out:
#                 movie_title  \
# 0       shadow in the cloud
# 1           the white tiger
# 2               locked down
# 3                   the dig
# 4          outside the wire
# ..                      ...
# 353  the tragedy of macbeth
# 354    a journal for jordan
# 355       american underdog
# 356                 memoria
# 357                     NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 353  Joel Coen (director/screenplay); Denzel Washin...
# 354  Denzel Washington (director); Virgil Williams ...
# 355  Erwin brothers (directors); Jon Erwin, David A...
# 356  Apichatpong Weerasethakul (director/acreenplay...
# 357                                                NaN
#
#                               genres  \
# 0                  Horror Action War
# 1                              Drama
# 2                 Comedy Crime Drama
# 3                      Drama History
# 4    Thriller Action Science Fiction
# ..                               ...
# 353                        Drama War
# 354                    Drama Romance
# 355                            Drama
# 356            Drama Fantasy Mystery
# 357                           Comedy
#
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Ramin Bahrani
# 2                                           Doug Liman
# 3                                          Simon Stone
# 4                                      Mikael Håfström
# ..                                                 ...
# 353                                          Joel Coen
# 354                                  Denzel Washington
# 355                                     Erwin brothers
# 356  Apichatpong Weerasethakul (director/acreenplay...
# 357                                                nan
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Chloë Grace Moretz  Taylor John Smith
# 1                                        Adarsh Gourav      Rajkummar Rao
# 2                                        Anne Hathaway   Chiwetel Ejiofor
# 3                                       Carey Mulligan      Ralph Fiennes
# 4                                       Anthony Mackie       Damson Idris
# ..                                                 ...                ...
# 353                                  Denzel Washington  Frances McDormand
# 354                                  Michael B. Jordan       Chanté Adams
# 355                                       Zachary Levi        Anna Paquin
# 356  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
# 357                                                nan                NaN
#
#               actor_3_name                                               comb
# 0             Beulah Koale  Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1    Priyanka Chopra Jonas  Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 2         Stephen Merchant  Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# 3               Lily James  Carey Mulligan Ralph Fiennes Lily James Simon ...
# 4            Emily Beecham  Anthony Mackie Damson Idris Emily Beecham Mika...
# ..                     ...                                                ...
# 353          Bertie Carvel  Denzel Washington Frances McDormand Bertie Car...
# 354        Jalon Christian  Michael B. Jordan Chanté Adams Jalon Christian...
# 355           Dennis Quaid  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 356         Jeanne Balibar  Apichatpong Weerasethakul (director/acreenplay...
# 357                    NaN                                                NaN
#
# [358 rows x 8 columns]

# %%
df_original['comb'] = df_original['actor_1_name'] + ' ' + df_original['actor_2_name'] + ' '+ df_original['actor_3_name'] + ' '+ df_original['director_name'] +' ' + df_original['genres']
df_original
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 5038        Scott Smith      Eric Mabius     Daphne Zuniga
# 5039            unknown      Natalie Zea     Valorie Curry
# 5040   Benjamin Roberds      Eva Boehnke     Maxwell Moody
# 5041        Daniel Hsia        Alan Ruck     Daniel Henney
# 5042           Jon Gunn      John August  Brian Herzlinger
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5038          Crystal Lowe                     Comedy Drama
# 5039         Sam Underwood     Crime Drama Mystery Thriller
# 5040        David Chandler            Drama Horror Thriller
# 5041           Eliza Coupe             Comedy Drama Romance
# 5042              Jon Gunn                      Documentary
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5038                            signed sealed delivered
# 5039                          the following
# 5040                               a plague so pleasant
# 5041                                   shanghai calling
# 5042                                  my date with drew
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5038  Eric Mabius Daphne Zuniga Crystal Lowe Scott S...
# 5039  Natalie Zea Valorie Curry Sam Underwood unknow...
# 5040  Eva Boehnke Maxwell Moody David Chandler Benja...
# 5041  Alan Ruck Daniel Henney Eliza Coupe Daniel Hsi...
# 5042  John August Brian Herzlinger Jon Gunn Jon Gunn...
#
# [5043 rows x 7 columns]

# %%
new_df = pd.concat([movies_info[0], movies_info[1], movies_info[2], movies_info[3], movies_info[4]], ignore_index=True)
df_final = df_original.append(new_df,ignore_index=True)
df_final = df_final.drop("Cast and crew",axis=1)
df_final['movie_title'] = df_final['movie_title'].str.replace('\xa0', ' ')
df_final
# Out:
# /var/folders/g_/c68jffzd7552c4ffzwzthm1h0000gn/T/ipykernel_84883/1430819214.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_final = df_original.append(new_df,ignore_index=True)
#                  director_name     actor_1_name        actor_2_name  \
# 0                James Cameron      CCH Pounder    Joel David Moore
# 1               Gore Verbinski      Johnny Depp       Orlando Bloom
# 2                   Sam Mendes  Christoph Waltz        Rory Kinnear
# 3            Christopher Nolan        Tom Hardy      Christian Bale
# 4                  Doug Walker      Doug Walker          Rob Walker
# ...                        ...              ...                 ...
# 6361        Kelly Fremon Craig   Rachel McAdams  Abby Ryder Fortson
# 6362  Josh Gordon & Will Speck    Anthony Ramos         Naomi Scott
# 6363              Olivia Wilde    Florence Pugh        Harry Styles
# 6364          Nicholas Stoller    Billy Eichner     Luke Macfarlane
# 6365                       nan              nan                 NaN
#
#               actor_3_name                                   genres  \
# 0                Wes Studi          Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                 Action Adventure Fantasy
# 2         Stephanie Sigman                Action Adventure Thriller
# 3     Joseph Gordon-Levitt                          Action Thriller
# 4                  unknown                              Documentary
# ...                    ...                                      ...
# 6361          Benny Safdie                             Drama Comedy
# 6362        Zachary Quinto           Science Fiction Comedy Romance
# 6363          Olivia Wilde                   Drama Mystery Thriller
# 6364            Ts Madison  Adventure Comedy Family Science Fiction
# 6365                   NaN                                   Comedy
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6361               are you there god? it's me, margaret
# 6362                                            distant
# 6363                                don't worry darling
# 6364                                               bros
# 6365                                                NaN
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6361  Rachel McAdams Abby Ryder Fortson Benny Safdie...
# 6362  Anthony Ramos Naomi Scott Zachary Quinto Josh ...
# 6363  Florence Pugh Harry Styles Olivia Wilde Olivia...
# 6364  Billy Eichner Luke Macfarlane Ts Madison Nicho...
# 6365                                                NaN
#
# [6366 rows x 7 columns]

# %%
df_final.to_csv('preprocessed_dataset.csv',index=False)
